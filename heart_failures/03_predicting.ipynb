# %% [markdown]
# ## Step 3 -  Predicting Heart Failure Death
#
# Load the saved model and perform prediction.

# %%
import pandas as pd
from pycaret.classification import *

# %%
df_predict = pd.read_csv("data/predict_dataset.csv")
print(df_predict.shape)
df_predict.head()
# Out:
# (10, 13)
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  70.0        0                        97         0               0.60
# 1  60.0        1                       754         1               0.40
# 2  45.0        0                      2442         1               0.30
# 3  70.0        0                       582         1               0.38
# 4  52.0        0                       190         1               0.38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   220000.0               0.9           138    1
# 1                    1   328000.0               1.2           126    1
# 2                    0   334000.0               1.1           139    1
# 3                    0    25100.0               1.1           140    1
# 4                    0   382000.0               1.0           140    1
#
#    smoking  time  DEATH_EVENT
# 0        0   186            0
# 1        0    91            0
# ...

# %%
saved_rf = load_model("models/random_forest")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(saved_rf, df_unseen)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 202  70.0        0                        97         0               0.60
# 114  60.0        1                       754         1               0.40
# 164  45.0        0                      2442         1               0.30
# 277  70.0        0                       582         1               0.38
# 292  52.0        0                       190         1               0.38
# 266  55.0        0                      1199         0               0.20
# 11   62.0        0                       231         0               0.25
# 171  52.0        0                      3966         0               0.40
# 238  65.0        1                       720         1               0.40
# 263  68.0        1                       157         1               0.60
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 202                    1  220000.00              0.90           138    1
# ...

# %% [markdown]
# # The End
