# %%
import pandas as pd
pd.options.display.max_colwidth = 1000

import warnings
warnings.filterwarnings('ignore')

from pycaret.nlp import *

# %%
df = pd.read_fwf('sms.txt', colspecs=[(0, 4), (4, None)], header=None, names=["class", "sms"])
print(df.shape)
df.head()
# Out:
# (5574, 2)
#   class  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                            sms
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# ...

# %%
nlp_setup = setup(data=df, target="sms")
# Out:
# <style type="text/css">
# </style>
# <table id="T_df7cd">
#   <thead>
#     <tr>
#       <th id="T_df7cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_df7cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_df7cd_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_df7cd_row0_col1" class="data row0 col1" >1208</td>
#     </tr>
#     <tr>
#       <td id="T_df7cd_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_df7cd_row1_col1" class="data row1 col1" >5574</td>
#     </tr>
#     <tr>
#       <td id="T_df7cd_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_df7cd_row2_col1" class="data row2 col1" >4138</td>
#     </tr>
#     <tr>
#       <td id="T_df7cd_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_df7cd_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
nlp_setup
# Out:
# ([['go', 'point', 'available', 'great', 'get'],
#   [],
#   ['free',
#    'entry',
#    'wkly',
#    'may',
#    'text',
#    'receive',
#    'entry',
#    'question',
#    'std',
#    'txt',
#    'rate',
#    'apply'],
#   ['say', 'early', 'hor', 'already', 'say'],
#   ['think', 'go', 'usf', 'live', 'around', 'though'],
#   ['week', 'word', 'fun', 'still', 'tb', 'send'],
#   ['even', 'brother', 'speak', 'treat', 'patent'],
#   ['set', 'press', 'copy', 'friend', 'callertune'],
#   ['value', 'select', 'valid', 'hour'],
#   ['month',
#    'entitled_update_latest_colour',
#    'camera',
#    'free',
#    'call',
#    'mobile',
#    'update',
#    'co',
#    'free'],
#   ['go',
#    'home',
#    'soon',
#    'want',
#    'talk',
#    'stuff',
#    'anymore',
#    'tonight',
#    'cry',
#    'enough',
#    'today'],
#   ['chance',
#    'win',
#    'cash',
#    'pound',
#    'send',
#    'cost',
#    'day',
#    'day',
#    'tsandcs',
#    'apply'],
# ...
